# %% [markdown]
# Import libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Read file

# %%
df = pd.read_csv('/content/drive/MyDrive/Iris.csv')

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
#divide test data and train data
train_df = df.sample(frac=.8);
test_df = df.sample(frac=.2);
train_df.reset_index(drop=True, inplace=True)
test_df.reset_index(drop=True, inplace=True)

# %%
test_df
# Out:
#      Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0    16            5.7           4.4            1.5           0.4
# 1    40            5.1           3.4            1.5           0.2
# 2   141            6.7           3.1            5.6           2.4
# 3     3            4.7           3.2            1.3           0.2
# 4    82            5.5           2.4            3.7           1.0
# 5    17            5.4           3.9            1.3           0.4
# 6     1            5.1           3.5            1.4           0.2
# 7    24            5.1           3.3            1.7           0.5
# 8    83            5.8           2.7            3.9           1.2
# 9    87            6.7           3.1            4.7           1.5
# 10  122            5.6           2.8            4.9           2.0
# 11   79            6.0           2.9            4.5           1.5
# 12   89            5.6           3.0            4.1           1.3
# ...

# %% [markdown]
# Main function

# %%
def KNN(k):
    for i in range(len(test_df)):
        s_list = []
        for j in range(len(train_df)):
            eq = (test_df['SepalLengthCm'][i] - train_df['SepalLengthCm'][j])**2 + \
                 (test_df['SepalWidthCm'][i] - train_df['SepalWidthCm'][j])**2 + \
                 (test_df['PetalLengthCm'][i] - train_df['PetalLengthCm'][j])**2 + \
                 (test_df['PetalWidthCm'][i] - train_df['PetalWidthCm'][j])**2

            s_list.append([eq, train_df['Species'][j]])

        s_list.sort(key=lambda x: x[0])
        top_k = s_list[:k]

        s = 0
        vg = 0
        vs = 0
        for n in top_k:
            if n[1] == "Iris-setosa":
                s += 1
            elif n[1] == "Iris-virginica":
                vg += 1
            elif n[1] == "Iris-versicolor":
                vs += 1



        if s > vg and s > vs:
            test_df.at[i, f"validate{k}"] = "Iris-setosa"
        elif vg > s and vg > vs:
            test_df.at[i, f"validate{k}"] = "Iris-virginica"
        else:
            test_df.at[i, f"validate{k}"] = "Iris-versicolor"

    return 0



test_df
# Out:
#      Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0    16            5.7           4.4            1.5           0.4
# 1    40            5.1           3.4            1.5           0.2
# 2   141            6.7           3.1            5.6           2.4
# 3     3            4.7           3.2            1.3           0.2
# 4    82            5.5           2.4            3.7           1.0
# 5    17            5.4           3.9            1.3           0.4
# 6     1            5.1           3.5            1.4           0.2
# 7    24            5.1           3.3            1.7           0.5
# 8    83            5.8           2.7            3.9           1.2
# 9    87            6.7           3.1            4.7           1.5
# 10  122            5.6           2.8            4.9           2.0
# 11   79            6.0           2.9            4.5           1.5
# 12   89            5.6           3.0            4.1           1.3
# ...

# %%
KNN_r3 = KNN(3)
KNN_r5 = KNN(5)
KNN_r7 = KNN(7)


for j in range(3,8,2):
  validation = 0
  for i in range(len(test_df)):
    if(test_df['Species'][i] == test_df[f'validate{j}'][i]):
      validation+=1
  print(f"The accuracy for {j} =" , validation/len(test_df)*100,"%")
# Out:
# The accuracy for 3 = 96.66666666666667 %
# The accuracy for 5 = 100.0 %
# The accuracy for 7 = 100.0 %

# %%
cols = ['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']
norm_train_df = pd.DataFrame()
norm_train_df[cols] = df[cols]
norm_test_df = pd.DataFrame()
norm_test_df[cols] = df[cols]



for col in cols:
    mean = train_df[col].mean()
    std = train_df[col].std()
    norm_train_df[col] = (train_df[col] - mean) / std
    mean = test_df[col].mean()
    std = test_df[col].std()
    norm_test_df[col] = (test_df[col] - mean) / std
norm_test_df['Species'] = test_df["Species"]
norm_train_df['Species'] = train_df["Species"]

norm_test_df.dropna()
# Out:
#     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm          Species
# 0       -0.180740      2.215913      -1.053218     -0.863858      Iris-setosa
# 1       -1.014922      0.389611      -1.053218     -1.120450      Iris-setosa
# 2        1.209565     -0.158279       1.247774      1.702058   Iris-virginica
# 3       -1.571044      0.024351      -1.165462     -1.120450      Iris-setosa
# 4       -0.458801     -1.436691       0.181460     -0.094084  Iris-versicolor
# 5       -0.597831      1.302762      -1.165462     -0.863858      Iris-setosa
# 6       -1.014922      0.572241      -1.109340     -1.120450      Iris-setosa
# 7       -1.014922      0.206981      -0.940975     -0.735563      Iris-setosa
# 8       -0.041709     -0.888800       0.293704      0.162508  Iris-versicolor
# 9        1.209565     -0.158279       0.742678      0.547395  Iris-versicolor
# 10      -0.319770     -0.706170       0.854921      1.188875   Iris-virginica
# ...

# %%
def KNNNormalized(k):
    for i in range(len(norm_test_df)):
        s_list = []
        for j in range(len(norm_train_df)):
            eq = (norm_test_df['SepalLengthCm'][i] - norm_train_df['SepalLengthCm'][j])**2 + \
                 (norm_test_df['SepalWidthCm'][i] - norm_train_df['SepalWidthCm'][j])**2 + \
                 (norm_test_df['PetalLengthCm'][i] - norm_train_df['PetalLengthCm'][j])**2 + \
                 (norm_test_df['PetalWidthCm'][i] - norm_train_df['PetalWidthCm'][j])**2
            s_list.append([eq, norm_train_df['Species'][j]])

        s_list.sort(key=lambda x: x[0])
        top_k = s_list[:k]

        s = 0
        vg = 0
        vs = 0
        for n in top_k:
            if n[1] == "Iris-setosa":
                s += 1
            elif n[1] == "Iris-virginica":
                vg += 1
            elif n[1] == "Iris-versicolor":
                vs += 1


        if s > vg and s > vs:
            norm_test_df.at[i, f"validate{k}"] = "Iris-setosa"
        elif vg > s and vg > vs:
            norm_test_df.at[i, f"validate{k}"] = "Iris-virginica"
        else:
            norm_test_df.at[i, f"validate{k}"] = "Iris-versicolor"

    return 0



norm_test_df.dropna()
# Out:
#     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm          Species
# 0       -0.180740      2.215913      -1.053218     -0.863858      Iris-setosa
# 1       -1.014922      0.389611      -1.053218     -1.120450      Iris-setosa
# 2        1.209565     -0.158279       1.247774      1.702058   Iris-virginica
# 3       -1.571044      0.024351      -1.165462     -1.120450      Iris-setosa
# 4       -0.458801     -1.436691       0.181460     -0.094084  Iris-versicolor
# 5       -0.597831      1.302762      -1.165462     -0.863858      Iris-setosa
# 6       -1.014922      0.572241      -1.109340     -1.120450      Iris-setosa
# 7       -1.014922      0.206981      -0.940975     -0.735563      Iris-setosa
# 8       -0.041709     -0.888800       0.293704      0.162508  Iris-versicolor
# 9        1.209565     -0.158279       0.742678      0.547395  Iris-versicolor
# 10      -0.319770     -0.706170       0.854921      1.188875   Iris-virginica
# ...

# %% [markdown]
# Accuracy with diffrent K`s

# %%
KNN_n3 = KNNNormalized(3)
KNN_n5 = KNNNormalized(5)
KNN_n7 = KNNNormalized(7)


for j in range(3,8,2):
  validation = 0
  for i in range(len(test_df)):
    if(norm_test_df['Species'][i] == norm_test_df[f'validate{j}'][i]):
      validation+=1
  print(f"The accuracy for {j} =" , validation/len(test_df)*100,"%")
# Out:
# The accuracy for 3 = 100.0 %
# The accuracy for 5 = 100.0 %
# The accuracy for 7 = 100.0 %
